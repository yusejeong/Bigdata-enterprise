# %%
import urllib.request   
import numpy as np  ## 백터, 행렬 데이터 전문 모듈 numpy
import requests
from bs4 import BeautifulSoup

# %%
print("검색하실 기업을 입력하세요.")
keyword=input("")
print("\n시작날짜를 입력하세요.(ex.2018-01-01)")
startdate=input("")
print("\n종료날짜를 입력하세요.(ex.2019-01-01)")
enddate=input("")
# Out:
# 검색하실 기업을 입력하세요.
# 카카오
#
# 시작날짜를 입력하세요.(ex.2018-01-01)
# 2017-01-01
#
# 종료날짜를 입력하세요.(ex.2019-01-01)
# 2018-01-01

# %%
client_id = "u27p_mRv4vyVbqBOL3Aa"
client_secret = "R7cve_jy7G"
url = "https://openapi.naver.com/v1/datalab/search";
bodys = "{\"startDate\":\"\",\"endDate\":\"\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"\",\"keywords\":[\"\"]}]}"
body=bodys[:14]+startdate+bodys[14:27]+enddate+bodys[27:78]+keyword+bodys[78:93]+keyword+bodys[93:]
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
f2=response_body.decode('utf-8')
f3=f2.split('},')
f3[0]=f3[0][-29:]
fn=np.array(f3)
fs=fn
for i in range(len(fn)):
    k=fn[i].find(":")
    fn[i]=fn[i][k:]
f3=f2.split('},')
f3[0]=f3[0][-29:]
fn=np.array(f3)
for i in range(len(fn)):
    k=0
    k=fn[i].find("ra")
    fn[i]=fn[i][(k+7):]
k=fn[-1].find('}')
fn[-1]=fn[-1][:k]
fn2=fn.astype('float32')
fn2=fn2.reshape(-1,1)
for i in range(1,len(fs)):
    k=fs[i].find(":")
    fs[i]=fs[i][k:]

# %%
fin1="\"ratio\":"+"100"
k=f2.index(fin1)
f0=f2[k-12:k-2]
f0=f0.replace('-','.')
url='https://search.naver.com/search.naver?where=news&query=&pd=3&ds=&de=&start=1'
url=url[:55]+keyword+url[55:64]+f0+url[64:68]+f0+url[68:]
name=keyword+".txt"
f = open(name, 'w', encoding='utf-8', newline='')

response = requests.get(url)
html = response.text
soup = BeautifulSoup(html, 'html.parser')
title_list = soup.select('._sp_each_title')
for tag in title_list:
    print(tag.text)
    f.write(tag.text)
f.close()
# Out:
# 인터넷은행 카카오뱅크, 문 열자마자 3만5천개 계좌 개설
# 카카오뱅크, 8시간만에 '10만계좌'…K뱅크보다 뜨겁다
# 카카오, 자원봉사 동아리 지원 캠페인 '봉사왕 나야 나' 시작
# 카카오뱅크, 18만계좌 돌파…시중은행 1년 실적을 12시간만에(종합)
# 카카오뱅크 출범, 보안상 문제없나?…"PC 뱅킹 NO, 본인 명의 한 개 기기에서...
# '인터넷 은행' 카카오뱅크 출격...8시간 만에 10만 명 돌파
# 카카오뱅크 출범 첫날부터 돌풍…한때 서버 마비
# [데일리안 오늘뉴스 종합]청주·괴산·천안 '특별재난지역' 지정, '문화계 블...
# 카카오뱅크 첫날 '돌풍'…기존 금융권 흔들 태풍 될까
# 카카오뱅크 개시 10시간 만에 15만 계좌 육박

# %%
f0
# Out:
# '2017.07.27'
